# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

messages = [
  {
    "role": "user",
    "content": [
      {"type": "text", "text": "이 이미지는 무엇을 나타내는 이미지인가요? 설명해주세요."},
      {
        "type": "image_url",
        "image_url": {
          "url": "https://plus.unsplash.com/premium_photo-1674062862036-6a9fc2b0014d?q=80&w=3464&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"
        }
      }
    ]
  }
]

response = client.chat.completions.create(
  model="gpt-5-mini",
  messages=messages
)

response
# Out:
# ChatCompletion(id='chatcmpl-CcRtFQ9201AgaQ9f482Cy8sPcthiY', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이미지에 보이는 장면을 설명하면 다음과 같습니다.\n\n- 한 여성이 바닥 매트에 누운 상태로 양손에 육각형 덤벨(아령)을 들고 가슴 쪽으로 밀어 올리는 동작(덤벨 프레스 계열의 근력 운동)을 하고 있습니다.\n- 여성은 운동복(라이트 블루 스포츠탑과 검정 레깅스)을 착용하고 있으며, 매트는 검은색, 바닥은 나무 바닥입니다.\n- 이미지 오른쪽 위에 다른 사람이 한 손을 내밀어 자세나 동작을 도와주고 있는 모습이 보입니다(트레이너가 지도를 하는 장면으로 보임).\n- 배경에는 추가 덤벨들이 놓여 있고, 사진 전체에 “Unsplash+” 워터마크가 반복되어 있습니다.\n- 전체적으로 실내에서 진행되는 개인 트레이닝 또는 운동 세션을 찍은 사진입니다.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1763279709, model='gpt-5-mini-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=917, prompt_tokens=1828, total_tokens=2745, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=704, rejected_prediction_tokens=0), prompt_to
# ...

# %%
import base64

def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode("utf-8")

image_path = "./data/art.jpeg"

base64_image = encode_image(image_path)

print(base64_image)
# Out:
# ...

# %%
messages = [
  {  
    "role": "user",
    "content": [
      {"type": "text", "text": "이 이미지는 무엇을 나타내는 이미지인가요? 설명해주세요."},
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{base64_image}"
        }
      }
    ]
  }
]


response = client.chat.completions.create(
  model="gpt-5-mini",
  messages=messages
)

response.choices[0].message.content
# Out:
# '이 이미지는 우주를 테마로 한 디지털 아트(혹은 일러스트)입니다. 주요 요소는 다음과 같습니다.\n\n- 배경 전체에 흩어진 무수한 별들과 성운 같은 가스 구름이 있어 깊고 넓은 우주감을 줍니다. 보라색·분홍·남색 계열의 색깔이 강하게 사용되어 극적으로 표현되어 있습니다.\n- 왼쪽 중앙에는 밝게 빛나는 성운(또는 성간 가스 구름)이 있고, 그 앞에 작은 행성 하나가 보입니다.\n- 중앙 오른쪽 쪽에는 표면에 음영이 진 비교적 큰 행성이 있으며, 위쪽에 매우 밝은 청색의 별(광원)이 있어 행성을 비추고 있습니다.\n- 오른쪽 끝 근처에도 작은 행성들과 빛나는 성단 같은 부분이 있어 다중 행성계나 은하 주변 풍경을 연상시킵니다.\n- 빛 번짐(lens flare)과 채도가 높은 색감, 그리고 세심한 음영 처리로 현실적인 사진이라기보다는 감성적·환상적으로 연출된 작품임을 알 수 있습니다.\n\n요약하면, 이 이미지는 보라·파랑 톤의 성운과 여러 행성, 밝은 별이 어우러진 상상 속 우주 풍경을 그려낸 예술 작품입니다. 원하시면 이미지의 색채·구도·분위기 같은 부분을 더 자세히 설명해 드리거나, 이 장면에 어울리는 짧은 설명문(캡션)을 만들어 드릴 수 있습니다. 어떤 도움을 더 원하시나요?'

# %%
seolleung_terrarosa_base64 = encode_image("./data/seollung.jpeg")
hongdae_base64 = encode_image("./data/hongdae.jpg")


messages = [
  {
    "role": "user",
    "content": [
      {
        "type": "text",
        "text": "두 카페의 차이점을 설명해 주세요."
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{seolleung_terrarosa_base64}"
        }
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{hongdae_base64}"
        }
      }
    ]
  }
]

response = client.chat.completions.create(
  model="gpt-5-mini",
  messages=messages
)

response.choices[0].message.content
# Out:
# '두 사진의 카페는 규모, 분위기, 인테리어와 용도에서 꽤 다른 인상을 줍니다. 주요 차이점을 정리하면 다음과 같습니다.\n\n- 규모와 구조\n  - 첫 번째 카페: 넓고 개방적인 대형 공간. 높이와 층고가 크고 메자닌(2층 구조)처럼 보이는 복층형 설계.\n  - 두 번째 카페: 소규모·단층형에 가까운 아담한 공간.\n\n- 채광과 조명\n  - 첫 번째: 천장에 걸린 펜던트 조명이 많아 은은하고 약간 어두운 분위기. 전반적으로 실내 조명이 강조된 느낌.\n  - 두 번째: 큰 창으로 들어오는 자연광이 많아 밝고 환한 분위기.\n\n- 인테리어 스타일\n  - 첫 번째: 공장형/인더스트리얼 느낌(노출천장·검은색 장치 등), 넓은 서가와 상품 진열대가 빽빽하게 배치되어 있음.\n  - 두 번째: 미니멀하고 현대적인 디자인. 스테인리스 카운터와 깔끔한 진열, 정돈된 디스플레이 테이블.\n\n- 용도 및 분위기\n  - 첫 번째: 북카페 겸 대형 라이프스타일 숍이나 서점 카페 같은 복합 공간으로, 쇼핑·탐색·여러 사람의 이용에 적합해 보임.\n  - 두 번째: 고급스러운 소형 북카페 또는 전문 커피숍 느낌으로, 조용히 책을 보거나 테이크아웃하기 좋은 분위기.\n\n- 좌석 배치와 이용성\n  - 첫 번째: 1층과 2층에 걸쳐 좌석이 분산되어 있고, 많은 사람들이 동시에 머무를 수 있는 구조.\n  - 두 번째: 좌석은 적고 카운터·상품 진열에 초점이 맞춰져 있어 머무르기보다는 구매·간단한 이용에 적합.\n\n- 색감과 소재\n  - 첫 번째: 어두운 톤(검정·회색)과 나무·금속 혼합, 전반적으로 무게감 있는 팔레트.\n  - 두 번째: 밝은 톤(화이트·우드·금속), 깔끔하고 세련된 느낌.\n\n요약하면 첫 카페는 대형 복합공간형(쇼핑·서점 기능이 강한 활기 있는 장소), 두 번째는 소형·모던한 전문 카페(정돈된 상품 진열과 밝은 분위기)라고 볼 수 있습니다. 필요하시면 어느 쪽이 더 공부·모임·데이트에 적합한지 추천도 드릴게요.'

# %%
oecd_rnd_2021_base64 = encode_image("./data/oecd_rnd_2021.png")
oecd_rnd_2022_base64 = encode_image("./data/oecd_rnd_2022.png")


messages = [
  {
    "role": "user",
    "content": [
      {
        "type": "text",
        "text": "첫번째는 2021년 데이터 이고, 두번째는 2022년 데이터 입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국 중심으로 설명해주세요."
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{oecd_rnd_2021_base64}"
        }
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{oecd_rnd_2022_base64}"
        }
      }
    ]
  }
]

response = client.chat.completions.create(
  model="gpt-5-mini",
  messages=messages
)

response.choices[0].message.content
# Out:
# "요청하신 두 그림(첫째: 2021년 기준 자료, 둘째: 2022년 기준 자료)을 바탕으로 한국 중심으로 변화와 의미를 정리해 드립니다. (그림에서 읽어낸 값은 차트에 표기된 수치를 근거로 한 근사치이며, 그림에 표시된 환율(첫째 1,143.96원/달러, 둘째 1,291.45원/달러)도 비교에 영향을 줍니다.)\n\n요약(핵심 결론)\n- 한국의 연구개발(R&D) 총지출(백만 US$ 기준)은 2021년 수준에서 2022년에 소폭 감소했습니다. (대략 2021년 약 89.3억 달러 → 2022년 약 87.2억 달러, 약 2~3% 감소로 보임)\n- 반면 GDP 대비 연구개발비 비중(연구집약도)은 크게 변하지 않았고, OECD 주요국 중 상위권(약 4%대 후반 ~ 5% 내외)을 유지하고 있습니다. 즉 국내 총지출(원화 기준)이나 비중 관점에서는 안정적(높은 수준 유지)이라고 볼 수 있습니다.\n- 절대 금액 기준으로는 미국·중국 등 상위국의 지출이 큰 폭으로 늘어 전체 순위에서 일부 변동이 있으나, 한국은 여전히 상위권(세계·OECD 내 상위 그룹)에 속합니다.\n\n세부 분석 및 해석\n1) 절대액(USD 기준) 변화\n- 글로벌 추세: 미국(약 7209억 → 8060억 US$), 중국(약 3535억 → 4335억 US$) 등 주요국의 연구개발비가 크게 증가했습니다. 총액 상위권 국가들의 절대 지출은 전반적으로 증가하는 모습입니다.\n- 한국: 차트에서 읽은 값으로는 2021→2022년 사이 약간 감소(약 89.3억 → 87.2억 US$). 감소 폭은 크지 않지만, 다른 국가들의 절대 증가에 비하면 상대적으로 정체 또는 소폭 감소한 모습입니다.\n\n2) GDP 대비 연구개발 비중(연구집약도)\n- 한국은 OECD 주요국 중에서도 높은 편에 속합니다(약 4%대 후반 내외로 표기됨). 2021→2022 기간에 큰 변동은 없고 상위권을 유지합니다.\n- 참고로 이 비중은 환율 영향이 아니라 국내 원화 기준 R&D 지출과 GDP 규모를 함께 고려한 비율이므로, 국
# ...
