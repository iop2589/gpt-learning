# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()

model = ChatOpenAI(model="gpt-4o-mini")
model.invoke("최근 로제가 발표한 신곡은 무엇인가요?")
# Out:
# AIMessage(content='로제는 2023년 12월에 신곡 "GONE"을 발표했습니다. 이 곡은 로제의 독특한 스타일과 감성을 잘 담고 있으며, 많은 팬들의 사랑을 받고 있습니다. 최신 소식이나 활동에 대한 더 자세한 정보는 공식 팬사이트나 소셜 미디어를 통해 확인하실 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 76, 'prompt_tokens': 19, 'total_tokens': 95, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DBdJ1CYwd1vtAyW7qsSqKGUCVtuJx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7f77-9e50-7710-b1f0-836fc57a63ab-0', usage_metadata={'input_tokens': 19, 'output_tokens': 76, 'total_tokens': 95, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults(results_separator=";\n")

result = search.invoke("최근 로제가 발표한 신곡은 무엇인가요?")

print(result)
# Out:
# Impersonate 'chrome_127' does not exist, using 'random'
# snippet: 한국 아이돌 가수 로제가 지난 18일 팝스타 브루노 마스와 함께 발표한 신곡 ‘아파트(APT.)’윤수일은 최근 MBC 라디오 프로그램에 나와 “졸지에 ‘아파트 2′가 나와서 이렇게 라디오를 통해 인사드린다., title: 로제가 쏜 “아~파트 아파트”… K팝·술게임에 세계가 취했다 | 조선일보, link: https://www.chosun.com/international/international_general/2024/10/24/GIZVGMYUF5EH7AD7GK5PGJWHDA/;
# snippet: 블랙핑크 로제가 최근 브루노 마스와 협력하여 발표한 신곡 ‘APT.’가 발매 즉시 글로벌 차트 정상에 오르며, 그녀의 높은 인기를 입증하고 있다., title: 차트 1위 블랙핑크, 재산200억 로제가 타는 이 차? | 브런치, link: https://brunch.co.kr/@c8ba214e7725479/8;
# snippet: 지난해 10월 로제가 세계적 가수 브루노 마스와 함께 발표한 곡 'APT.'(아파트)가 최근 빌보드 메인 차트인 '핫 100'에서 2주 연속 3위를 차지하며 대중적 인기를 과시하고 있기 때문이다., title: 2년간 K팝 잊은 그래미…내년 로제가 자존심 회복시킬까 [N초점] - 뉴스1, link: https://www.news1.kr/entertain/music/5682705;
# snippet: О сервисе Прессе Авторские права Связаться с нами Авторам Рекламодателям..., title: [ENG] 로제가 최근 꽂힌 핫소스는? 로제가 불러주는... - YouTube, link: https://www.youtube.com/watch?v=Fd_En3y2amo

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

question_answering_prompt = ChatPromptTemplate.from_messages(
  [
    (
      "system", "사용자의 질문에 대해 아래 context에 기반하여 답변하라.:\n\n{context}",
    ),
    MessagesPlaceholder(variable_name="messages"),
  ]
)

document_chain = question_answering_prompt | model

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory

chat_history = InMemoryChatMessageHistory()

chat_history.add_user_message("요즘 로제가 발표한 신곡을 무엇인가요?")

# %%
answer = document_chain.invoke(
  {
    "context": result,
    "messages": chat_history.messages
  }
)

chat_history.add_ai_message(answer)

print(answer)
# Out:
# content="로제가 최근 발표한 신곡은 브루노 마스와 협력한 'APT.'입니다. 이 곡은 발매 즉시 글로벌 차트에서 높은 성적을 거두며 그녀의 인기와 실력을 다시 한번 입증하고 있습니다." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 470, 'total_tokens': 524, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_414ba99a04', 'id': 'chatcmpl-DBdX8eTzJ7EbiOARJkCjii4aJtigG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c7f84-f2b2-7211-84f1-1fedabcd7e1f-0' usage_metadata={'input_tokens': 470, 'output_tokens': 54, 'total_tokens': 524, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

wrapper = DuckDuckGoSearchAPIWrapper(region="kr-kr", time="w") # 한국지역 기준 (kr-kr) 최근 1주일 기준 (w)

# %%
search = DuckDuckGoSearchResults(
  api_wrapper=wrapper,
  source="news",
  results_separator=";\n"        
)

docs = search.invoke("로제의 신곡 APT에 대한 반응")

print(docs)
# Out:
# snippet: 이후 23일에는 최근 1년간 최대 거래량인 5095만3659주로 폭발적인 증가세를 보였다. 이처럼 폭발적인 거래량을 나타낸 데엔 로제의 신곡 ‘아파트’가 한몫했다., title: [스타앤스톡] 블랙핑크 로제의 힘…‘아파트’로 YG플러스 주가 142..., link: https://www.ftoday.co.kr/news/articleView.html?idxno=331101;
# snippet: 투자자들 반응 .블랙핑크 로제의 신곡 ‘아파트’가 세계적으로 주목받으며, YG PLUS의 주가 상승세를 이끌었습니다., title: 블랙핑크 로제의 '아파트' 흥행, YG PLUS 주가 폭등, link: https://radiobox.net/블랙핑크-로제의-아파트-흥행-yg-plus-주가-폭등/;
# snippet: 로제의 신곡 ‘APT’를 AI로 커버해보세요!파트4: APT 커버곡에 대한 FAQs. Q1: APT 커버곡을 만들기 위해 어떤 도구가 필요하나요?, title: 로제 신곡 ‘APT’, AI로 손쉽게 만드는 아파트 커버곡 방법, link: https://kr.topmediai.com/ai-music/apt-song-cover/;
# snippet: 블랙핑크 멤버 로제의 신곡 ‘아파트’(APT.), title: “아파트, 아파트” 외치며 ‘소맥’ 말아준 로제…‘이 회사’ 주가도 날았다..., link: https://www.mk.co.kr/news/business/11152093

# %%
docs = search.invoke("site:ytn.co.kr 강북 모텔")

print(docs)
# Out:
# snippet: 2 days ago - ' 강북 모텔 연쇄 살인' 사건을 수사하는 경찰이 여성과 접촉했던 인물들에 대한 전수 조사를 벌이고 있는 것으로 YTN 취재 결과 확인됐습니다.피해자에게 보냈던 문자메..., title: [사회][단독] 경찰, '모텔 살인' 피의자 접촉 대상 전수조사..."유사 패턴 확인 목적" | YTN, link: https://www.ytn.co.kr/_ln/0103_202602211355516489;
# snippet: 2 days ago - ' 강북 모텔 연쇄 살인' 사건을 수사하는 경찰이 여성과 접촉했던 인물들에 대한 전수 조사를 벌이고 있는 것으로 YTN 취재 결과 확인됐습니다.연쇄살인 피의자에 대한 이..., title: [사회][단독] 경찰, '모텔 살인' 피의자 접촉자 전수조사...'사이코패스 검사' 결과 이르면 다음 주 | YTN, link: https://www.ytn.co.kr/_ln/0103_202602211558545942;
# snippet: 4 days ago - 00:00 [단독] 모텔 연쇄 살인 20대 살인죄 적용…챗GPT에 '수면제 과량' 검색(2월 19일, 배민혁 기자) 02:27 '모텔 연쇄 사망' 피의자 곧 송치...살인죄도 검토(2월 18일, 윤태인 기자) 04:03 [자막뉴스] "재우려고 했을 뿐"...'연쇄 사망' 피의자의 수상한 정황(2월 15일, 이 선 에디터) 05:42 [자막뉴스] "투약량 2배 늘려 남성들에"...'모텔 사망' 피의자 정황에 살인죄 검토(2월 15일, 이 선 에디터) 08:24 20대 남성들 죽음으로 이르게 한 '죽음의 칵테일' [Y녹취록](2월 13일, 김대천 에디터) 12:00 모텔서 남성 2명 연달아 사망...함께 투숙한 여성 체포(2월 11일, 윤태인 기자) 제작 : 최지혜 [저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지], title: [뉴스모아] 완전범죄 노린 여성의 최후… '챗GPT 검색 기록'에 덜미 잡혀 | YTN, link: https://www.ytn.co.kr/_ln/0522_202602191417056830;
# snippet: 4 days ago - YTN VOD, 클립영상 한 눈에 보고 즐기기, title: 뉴스특보 | YTN, link: https://www.ytn.co.kr/replay/view.php?idx=15&key=72978

# %%
links = []

for doc in docs.split(";\n"):
  print(doc)
  link = doc.split("link:")[1].strip()
  links.append(link)

print(links)
# Out:
# snippet: 2 days ago - ' 강북 모텔 연쇄 살인' 사건을 수사하는 경찰이 여성과 접촉했던 인물들에 대한 전수 조사를 벌이고 있는 것으로 YTN 취재 결과 확인됐습니다.피해자에게 보냈던 문자메..., title: [사회][단독] 경찰, '모텔 살인' 피의자 접촉 대상 전수조사..."유사 패턴 확인 목적" | YTN, link: https://www.ytn.co.kr/_ln/0103_202602211355516489
# snippet: 2 days ago - ' 강북 모텔 연쇄 살인' 사건을 수사하는 경찰이 여성과 접촉했던 인물들에 대한 전수 조사를 벌이고 있는 것으로 YTN 취재 결과 확인됐습니다.연쇄살인 피의자에 대한 이..., title: [사회][단독] 경찰, '모텔 살인' 피의자 접촉자 전수조사...'사이코패스 검사' 결과 이르면 다음 주 | YTN, link: https://www.ytn.co.kr/_ln/0103_202602211558545942
# snippet: 4 days ago - 00:00 [단독] 모텔 연쇄 살인 20대 살인죄 적용…챗GPT에 '수면제 과량' 검색(2월 19일, 배민혁 기자) 02:27 '모텔 연쇄 사망' 피의자 곧 송치...살인죄도 검토(2월 18일, 윤태인 기자) 04:03 [자막뉴스] "재우려고 했을 뿐"...'연쇄 사망' 피의자의 수상한 정황(2월 15일, 이 선 에디터) 05:42 [자막뉴스] "투약량 2배 늘려 남성들에"...'모텔 사망' 피의자 정황에 살인죄 검토(2월 15일, 이 선 에디터) 08:24 20대 남성들 죽음으로 이르게 한 '죽음의 칵테일' [Y녹취록](2월 13일, 김대천 에디터) 12:00 모텔서 남성 2명 연달아 사망...함께 투숙한 여성 체포(2월 11일, 윤태인 기자) 제작 : 최지혜 [저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지], title: [뉴스모아] 완전범죄 노린 여성의 최후… '챗GPT 검색 기록'에 덜미 잡혀 | YTN, link: https://www.ytn.co.kr/_ln/0522_202602191417056830
# snippet: 4 days ago - YTN VOD, 클립영상 한 눈에 보고 즐기기, title: 뉴스특보 | YTN, link: https://www.ytn.co.kr/replay/view.php?idx=15&key=72978
# ['https://www.ytn.co.kr/_ln/0103_202602211355516489', 'https://www.ytn.co.kr/_ln/0103_202602211558545942', 'https://www.ytn.co.kr/_ln/0522_202602191417056830', 'https://www.ytn.co.kr/replay/view.php?idx=15&key=72978']

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
  web_paths=links,
  bs_get_text_kwargs={"strip": True},
)

page_contents = []
async for doc in loader.alazy_load():
  page_contents.append(doc)

for content in page_contents:
  print(content)
  print('--------------------------------')
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Fetching pages: 100%|##########| 4/4 [00:00<00:00, 10.50it/s]
# page_content='[사회][단독] 경찰, '모텔 살인' 피의자 접촉 대상 전수조사..."유사 패턴 확인 목적" | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경동계올림픽정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램[단독] 경찰, '모텔 살인' 피의자 접촉 대상 전수조사..."유사 패턴 확인 목적"검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기단독경찰, '모텔 살인' 피의자 접촉 대상 전수조사..."유사 패턴 확인 목적"2026.02.21. 오후 1:55.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기경찰, '강북 모텔 연쇄 살인' 20대 김 모 씨 송치경찰, 여죄 수사 진행 중…"추가 피해자 여부 집중""포렌식 조사 통해 확인된 접촉 대상 전수조사"AD[앵커]'강북 모텔 연쇄 살인' 사건을 수사하는 경찰이 여성과 접촉했던 인물들에 대한 전수 조사를 벌이고 있는 것으로 YTN 취재 결과 확인됐습니다.피해자에게 보냈던 문자메시지와 유사한 패턴을 확인하겠다는 건데, 이른바 '사이코패스 검사' 결과도 이르면 다음 주에 나옵니다.취재 기자 연결해, 자세히 알아보겠습니다.송수현 기자!'강북 모텔 연쇄 살인' 사건 조사는 어떻게 진행되고 있죠?[기자]네, 서울 강북경찰서는 그제(19일) 살인 등 혐의를 받는 20대 여성 김 모 씨를 구속 송치했습니다.현재까지 파악된 피해자 3명에 대한 수사 결과는 검찰에 넘겼는데, 추가 피해자가 있는지 수사를 이어가고 있습니다.특히 경찰은 김 씨의 휴대전화를 포렌식해 김 씨와 접촉한 사람들에 대한 전수 조사에 나선 것으로 YTN 취재 결과 확인됐습니다.경찰은 김 씨와 통화했거나 메시지를 주고받은 기록이 있는 인물들에게 한 명 한 명 연락해 보면서, 범죄 피해를 봤는지를 확인하는 작업을 하고 있다고 설명했습니다.앞서 김 씨가 범행 현장인 모텔을 나서면서 피해자에게 남긴 문자 내역 등을 바탕으로, 이와 비슷한 문구나 유사한 패턴이 나오는 사람들을 접촉하겠다는 계획입니다.첫 번째 피해자가 발생했던 지난해 12월 이후부터의 기록을 집중적으로 확인하고 있는데, 조사 범위는 계속 확대하겠다고 밝혔습니다.[앵커]피의자에 대한 '사이코패스 검사'도 했다는데, 결과는 언제쯤 나오나요?[기자]네, 경찰은 지난 설 연휴에 김 씨에 대한 심리 분석 검사를 진행했습니다.심리 분야 전문가를 투입해 진행된 이른바 '사이코패스 검사'는 현재 결과 분석 단계에 있습니다.검사 결과는 이르면 다음 주 후반에 나올 예정입니다.공식 명칭은 PCL-R 검사로, 전문가들이 피의자와 장시간 면담을 진행하면서 사이코패스 성향을 20개 항목으로 나눠 분석합니다.항목당 2점 만점으로 분석해 총 40점 만점에 25점 이상이 나올 경우 사이코패스로 판정합니다.앞서 10명을 살해한 강호순, 또래 여성을 무참히 살해했던 정유정 등이 검사에서 25점 이상을 받아 사이코패스로 분류됐습니다.[앵커]경찰이 심리검사까지 한 계기는 뭔가요?[기자]네. 경찰은 모든 피의자를 대상으로 이런 '사이코패스 검사'를 하는 것은 아니라고 밝혔습니다.그러면서 조사 과정에서 김 씨가 합리적인 대답을 내놓지 않아 심리검사를 의뢰하게 됐다고 설명했습니다.답변에 일관성이 없다는 건데, 경찰이 조사에서 여러 증거를 제시해도 김 씨는 "재우려고 범행했다"는 대답만 반복하고 있다는 겁니다.앞서 김 씨는 경찰 조사에서 자신이 정신과에서 처방받은 수면제를 숙취해소제에 탔다고 진술했는데요.피해 남성들과 의견 충돌이 생겨 상대방을 재우려고 약을 탄 음료를 먹였다는 게 김 씨 주장입니다.심리분석 결과가 나오면 정확한 범행 동기에 대한 윤곽이 드러날지 주목됩니다.지금까지 사회부에서 YTN 송수현입니다.영상편집 : 양영운YTN 송수현 (sandy@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]AD2026 밀라노-코르티나 올림픽사회기사목록 전체보기'금 3천 돈' 챙겨 잠적했던 금은방 주인 구속..."증거인멸·도망 우려"조희대, 재차 숙의 요청..."헌법 개정 사항일 수 있어"수도권제1순환고속도로 화물차·SUV 추돌...2명 경상'성폭력 의혹' 색동원 시설장 이번 주 송치..."추가 수사 절실"YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0103_202602211355516489', 'title': '[사회][단독] 경찰, \'모텔 살인\' 피의자 접촉 대상 전수조사..."유사 패턴 확인 목적" | YTN', 'description': '경찰, ', 'language': 'ko'}
# --------------------------------
# page_content='[사회][단독] 경찰, '모텔 살인' 피의자 접촉자 전수조사...'사이코패스 검사' 결과 이르면 다음 주 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경동계올림픽정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램[단독] 경찰, '모텔 살인' 피의자 접촉자 전수조사...'사이코패스 검사' 결과 이르면 다음 주검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기단독경찰, '모텔 살인' 피의자 접촉자 전수조사...'사이코패스 검사' 결과 이르면 다음 주2026.02.21. 오후 3:58.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD[앵커]'강북 모텔 연쇄 살인' 사건을 수사하는 경찰이 여성과 접촉했던 인물들에 대한 전수 조사를 벌이고 있는 것으로 YTN 취재 결과 확인됐습니다.연쇄살인 피의자에 대한 이른바 '사이코패스 검사' 결과도 이르면 다음 주에 나옵니다.취재 기자 연결해, 자세히 알아보겠습니다. 송수현 기자!'강북 모텔 연쇄 살인' 사건 조사는 어떻게 진행되고 있죠.[기자]네, 서울 강북경찰서는 그제(19일) 살인 등 혐의를 받는 20대 여성 김 모 씨를 구속 송치했습니다.현재까지 파악된 피해자 3명에 대한 수사 결과는 검찰에 넘겼는데, 추가 피해자가 있는지 수사를 이어가고 있습니다.특히 경찰은 김 씨의 휴대전화를 포렌식해 김 씨와 접촉한 사람들에 대한 전수 조사에 나선 것으로 YTN 취재 결과 확인됐습니다.경찰은 김 씨와 통화했거나 메시지를 주고받은 기록이 있는 인물들에게 한 명 한 명 연락해 보면서, 범죄 피해를 봤는지를 확인하는 작업을 하고 있다고 설명했습니다.앞서 김 씨가 범행 현장인 모텔을 나서면서 피해자에게 남긴 문자 내역 등을 바탕으로, 이와 비슷한 문구나 유사한 패턴이 나오는 사람들을 조사하겠다는 겁니다.첫 번째 피해자가 발생했던 지난해 12월 이후부터의 기록을 집중적으로 확인하고 있는데, 조사 범위는 계속 확대하겠다는 계획입니다.[앵커]피의자에 대한 '사이코패스 검사'도 했다는데, 결과는 언제쯤 나오나요.[기자]네, 경찰은 지난 설 연휴에 김 씨에 대한 심리 분석 검사를 진행했습니다.심리 분야 전문가를 투입해 진행된 이른바 '사이코패스 검사'는 현재 결과 분석 단계에 있습니다.검사 결과는 이르면 다음 주 후반에 나올 예정입니다.공식 명칭은 PCL-R 검사로, 전문가들이 피의자와 장시간 면담을 진행하면서 사이코패스 성향을 20개 항목으로 나눠 분석합니다.항목당 2점 만점으로 분석해 총 40점 만점에 25점 이상이 나올 경우 사이코패스로 판정합니다.앞서 10명을 살해한 강호순, 또래 여성을 무참히 살해했던 정유정 등이 검사에서 25점 이상을 받아 사이코패스로 분류됐습니다.[앵커]경찰이 심리검사까지 한 계기는 뭔가요.[기자]네. 경찰은 모든 피의자를 대상으로 이런 '사이코패스 검사'를 하는 것은 아니라고 밝혔습니다.그러면서 조사 과정에서 김 씨가 합리적인 대답을 내놓지 않아 심리검사를 의뢰하게 됐다고 설명했습니다.답변에 일관성이 없다는 건데, 경찰이 조사에서 여러 증거를 제시해도 김 씨는 "재우려고 범행했다"는 대답만 반복하고 있다는 겁니다.앞서 김 씨는 경찰 조사에서 자신이 정신과에서 처방받은 수면제를 숙취해소제에 탔다고 진술했는데요.피해 남성들과 의견 충돌이 생겨 상대방을 재우려고 약을 탄 음료를 먹였다는 게 김 씨 주장입니다.심리분석 결과가 나오면 정확한 범행 동기에 대한 윤곽이 드러날지 주목됩니다.지금까지 사회부에서 YTN 송수현입니다.영상편집 ; 양영운YTN 송수현 (sandy@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]AD2026 밀라노-코르티나 올림픽사회기사목록 전체보기'금 3천 돈' 챙겨 잠적했던 금은방 주인 구속..."증거인멸·도망 우려"조희대, 재차 숙의 요청..."헌법 개정 사항일 수 있어"수도권제1순환고속도로 화물차·SUV 추돌...2명 경상'성폭력 의혹' 색동원 시설장 이번 주 송치..."추가 수사 절실"YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0103_202602211558545942', 'title': "[사회][단독] 경찰, '모텔 살인' 피의자 접촉자 전수조사...'사이코패스 검사' 결과 이르면 다음 주 | YTN", 'description': ' ', 'language': 'ko'}
# --------------------------------
# page_content='[뉴스모아] 완전범죄 노린 여성의 최후… '챗GPT 검색 기록'에 덜미 잡혀 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경동계올림픽정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램[뉴스모아] 완전범죄 노린 여성의 최후… '챗GPT 검색 기록'에 덜미 잡혀검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기[뉴스모아] 완전범죄 노린 여성의 최후… '챗GPT 검색 기록'에 덜미 잡혀2026.02.19. 오후 2:17.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD00:00 [단독] 모텔 연쇄 살인 20대 살인죄 적용…챗GPT에 '수면제 과량' 검색(2월 19일, 배민혁 기자)02:27 '모텔 연쇄 사망' 피의자 곧 송치...살인죄도 검토(2월 18일, 윤태인 기자)04:03 [자막뉴스] "재우려고 했을 뿐"...'연쇄 사망' 피의자의 수상한 정황(2월 15일, 이 선 에디터)05:42 [자막뉴스] "투약량 2배 늘려 남성들에"...'모텔 사망' 피의자 정황에 살인죄 검토(2월 15일, 이 선 에디터)08:24 20대 남성들 죽음으로 이르게 한 '죽음의 칵테일' [Y녹취록](2월 13일, 김대천 에디터)12:00 모텔서 남성 2명 연달아 사망...함께 투숙한 여성 체포(2월 11일, 윤태인 기자)제작 : 최지혜[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]AD2026 밀라노-코르티나 올림픽YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0522_202602191417056830', 'title': "[뉴스모아] 완전범죄 노린 여성의 최후… '챗GPT 검색 기록'에 덜미 잡혀 | YTN", 'description': '00:00 [단독] 모텔 연쇄 살인 20대 살인죄 적용…챗GPT에 ', 'language': 'ko'}
# --------------------------------
# page_content='뉴스특보 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경동계올림픽정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기뉴스특보 02월 19일 13:30 ~ 15:00뉴스특보2026.02.19. 오후 6:32글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]최신 회차많이 보는더보기추천 콘텐츠재생뉴스퀘어 8PM뉴스퀘어 8PM2026년 02월 23일재생[돌발영상] 불난 집에 부채질이 제맛?New 돌발영상2026년 02월 23일재생뉴스PLUS뉴스PLUS2026년 02월 23일재생뉴스ON뉴스ON2026년 02월 23일재생뉴스퀘어 2PM뉴스퀘어 2PM2026년 02월 23일재생뉴스NOW뉴스NOW2026년 02월 23일재생룰라 브라질 대통령 국빈 방한…청와대 공식 환영식현장생중계2026년 02월 23일재생뉴스퀘어 10AM뉴스퀘어 10AM2026년 02월 23일재생뉴스UP뉴스UP2026년 02월 23일재생[팩트추적 예고] 고령 운전자 사고 급증…면허 반납만이 정답인가FACT 추적2026년 02월 23일재생뉴스START뉴스START2026년 02월 23일YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/replay/view.php?idx=15&key=72978', 'title': '뉴스특보 | YTN', 'description': '뉴스특보', 'language': 'ko'}
# --------------------------------
